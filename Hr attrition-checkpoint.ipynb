# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#let us import our data set
data=pd.read_csv("Desktop\WA_Fn-UseC_-HR-Employee-Attrition.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ###### Eda

# %% [markdown]
# Let us check the shape of data set

# %%
data.shape
# Out:
# (1470, 35)

# %% [markdown]
# so our data set has 1470 and 35 columns including our Target variable which is attrition

# %% [markdown]
# Let us find the null values

# %%
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Great our data set does not have any missing values so we can proceed

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# So the age column does not play a vital role here so let us remove it

# %%
df=data.drop(columns=['Age'])
df=data.drop(columns=['EmployeeCount'])
df=data.drop(columns=['Over18'])

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# so after removing the age column this is how data looks like

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(df['Attrition'])
plt.title('Attrition')
# Out:
# Text(0.5, 1.0, 'Attrition')

# %% [markdown]
# There is a class imbalance issue which need to be resolved later

# %% [markdown]
# Label encoding

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from pandas.plotting import scatter_matrix
labelencoder=LabelEncoder()
for column in df.columns:
    df[column]=labelencoder.fit_transform(df[column])

# %% [markdown]
# Let us describe our data set

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     18.923810     0.161224        1.607483   443.074830     1.260544
# std       9.135373     0.367863        0.665455   253.513199     0.527792
# min       0.000000     0.000000        0.000000     0.000000     0.000000
# 25%      12.000000     0.000000        1.000000   225.000000     1.000000
# 50%      18.000000     0.000000        2.000000   447.000000     1.000000
# 75%      25.000000     0.000000        2.000000   660.000000     2.000000
# max      42.000000     1.000000        2.000000   885.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           8.192517     1.912925        2.247619            0.0
# std            8.106864     1.024165        1.331369            0.0
# ...

# %% [markdown]
# Now let us see the distribution of data

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=23:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Identifying outliers

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=23:
        ax=plt.subplot(6,4,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
        
        plotnumber+=1
plt.tight_layout()

# %% [markdown]
# The column Num compnies worked has Outliers

# %%
y=df['Attrition']
x=df.drop(columns=['Attrition'],axis=1)

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      23               2        624           2                 0          1
# 1      31               1        113           1                 7          0
# 2      19               2        805           1                 1          1
# 3      15               1        820           1                 2          3
# 4       9               2        312           1                 1          0
# ...   ...             ...        ...         ...               ...        ...
# 1465   18               1        494           1                22          1
# 1466   21               2        327           1                 5          0
# 1467    9               2         39           1                 3          2
# 1468   31               1        579           2                 1          2
# 1469   16               2        336           1                 7          2
#
# ...

# %% [markdown]
# Here we have splitted our data in to two filed where our Target variable is stored in Y and remaining are stored in X.

# %% [markdown]
# Let us plot the distribution

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in x:
    if plotnumber<=23:
        ax=plt.subplot(6,4,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('class',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Let us use a heat map to find the correlation

# %%
cor=df.corr()

# %%
cor
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010557
# Attrition                -0.159205   1.000000        0.000074  -0.056605
# BusinessTravel            0.024751   0.000074        1.000000  -0.004103
# DailyRate                 0.010557  -0.056605       -0.004103   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007796
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004738
# Education                 0.208034  -0.031373        0.000757  -0.016550
# EducationField           -0.040873   0.026846        0.023724   0.038129
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber           -0.010349  -0.010369       -0.015810  -0.051861
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018462
# Gender                   -0.036311   0.029453       -0.032981  -0.011194
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(cor,annot=True,linewidths=6,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As the data set is categorical we will not remove the outliers And skewness

# %% [markdown]
# Class imbalance issue

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()

# %%
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    1233
# 0    1233
# Name: Attrition, dtype: int64

# %% [markdown]
# Model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ###### Finding best random state

# %%
from sklearn.tree import DecisionTreeClassifier
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    mod=DecisionTreeClassifier()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Best Accuracy is:",maxAccu,"on Random state:",maxRs)
# Out:
# Best Accuracy is: 0.8432432432432433 on Random state: 36

# %% [markdown]
# best accuracy is 84% and random state is 36

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRs)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred=DTC.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83       357
#            1       0.83      0.87      0.85       383
#
#     accuracy                           0.84       740
#    macro avg       0.84      0.84      0.84       740
# weighted avg       0.84      0.84      0.84       740

# %% [markdown]
# Decision Tree gives 84% accuracy

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
pred=RFC.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91       357
#            1       0.94      0.89      0.91       383
#
#     accuracy                           0.91       740
#    macro avg       0.91      0.91      0.91       740
# weighted avg       0.91      0.91      0.91       740

# %% [markdown]
# Random forest gives 91% accuracy

# %%
sv=SVC()
sv.fit(x_train,y_train)
pred=sv.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.68      0.65       357
#            1       0.67      0.61      0.64       383
#
#     accuracy                           0.64       740
#    macro avg       0.65      0.65      0.64       740
# weighted avg       0.65      0.64      0.64       740

# %% [markdown]
# Support vector classifier gives 64% accuracy

# %% [markdown]
# Upon reviewing the above outputs the Random forest classifier gives 91% accuracy.So to choose the best model we will use cross validation Score.

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# 0.6553916778214846

# %% [markdown]
# Decision Tree gives 65.3%

# %%
print(cross_val_score(RFC,x,y,cv=5).mean())
# Out:
# 0.7766578249336871

# %% [markdown]
# Random fores gives 77%

# %%
print(cross_val_score(sv,x,y,cv=5).mean())
# Out:
# 0.49841177291801825

# %% [markdown]
# Support vector gives 49%

# %% [markdown]
# So our random forest classifier gives the less difference so we will consider this a best model

# %% [markdown]
# ## HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
#random forest classifier
parameters={'n_estimators':[200,700],
           'max_features':['auto','sqrt','log2'],
           'max_depth':[4,5,6,7,8],
           'criterion':['gini','entropy']}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 700]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
Final_mod1=RandomForestClassifier(criterion='gini',max_depth=8,max_features='auto',n_estimators=200)
Final_mod1.fit(x_train,y_train)
pred=Final_mod1.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 89.45945945945945

# %% [markdown]
# ###### After doing Hyper parmater Tuning were are able to find that the Random Forest classifier Gives us 89% accuracy

# %%
import joblib
joblib.dump(Final_mod,"Finalmodel1.pkl")
# Out:
# ['Finalmodel1.pkl']
